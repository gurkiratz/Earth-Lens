# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = "/content/public-disasters.csv"
df = pd.read_csv(file_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1066 entries, 0 to 1065
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DisNo.                       1066 non-null   object
#  1   Disaster Subgroup            1066 non-null   object
#  2   Disaster Type                1066 non-null   object
#  3   Disaster Subtype             1066 non-null   object
#  4   Event Name                   151 non-null    object
#  5   ISO                          1066 non-null   object
#  6   Country                      1066 non-null   object
#  7   Subregion                    1066 non-null   object
#  8   Region                       1066 non-null   object
#  9   Location                     1064 non-null   object
#  10  Origin                       360 non-null    object
#  11  Associated Types             441 non-null    object
#  12  AID Contribution ('000 US$)  14 non-null     float64
#  13  Magnitude                    398 non-null    float64
#  14  Magnitude Scale              1029 non-null   object
#  15  Latitude                     152 non-null    float64
#  16  Longitude                    152 non-null    float64
#  17  Start Year                   1066 non-null   int64
#  18  Start Month                  1066 non-null   int64
#  19  Start Day                    1008 non-null   float64
#  20  End Year                     1066 non-null   int64
#  21  End Month                    1066 non-null   int64
#  22  End Day                      1009 non-null   float64
#  23  Total Deaths                 869 non-null    float64
#  24  No. Injured                  285 non-null    float64
#  25  No. Affected                 498 non-null    float64
#  26  No. Homeless                 145 non-null    float64
#  27  Total Affected               704 non-null    float64
#  28  Total Damage ('000 US$)      605 non-null    float64
# dtypes: float64(12), int64(4), object(13)
# memory usage: 241.6+ KB

# %%
#remove COuntry India and Bermuda
df = df[~df['Country'].isin(['India', 'Bermuda'])]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 682 entries, 1 to 1064
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DisNo.                       682 non-null    object
#  1   Disaster Subgroup            682 non-null    object
#  2   Disaster Type                682 non-null    object
#  3   Disaster Subtype             682 non-null    object
#  4   Event Name                   115 non-null    object
#  5   ISO                          682 non-null    object
#  6   Country                      682 non-null    object
#  7   Subregion                    682 non-null    object
#  8   Region                       682 non-null    object
#  9   Location                     681 non-null    object
#  10  Origin                       169 non-null    object
#  11  Associated Types             319 non-null    object
#  12  AID Contribution ('000 US$)  0 non-null      float64
#  13  Magnitude                    243 non-null    float64
#  14  Magnitude Scale              679 non-null    object
#  15  Latitude                     75 non-null     float64
#  16  Longitude                    75 non-null     float64
#  17  Start Year                   682 non-null    int64
#  18  Start Month                  682 non-null    int64
#  19  Start Day                    656 non-null    float64
#  20  End Year                     682 non-null    int64
#  21  End Month                    682 non-null    int64
#  22  End Day                      656 non-null    float64
#  23  Total Deaths                 506 non-null    float64
#  24  No. Injured                  199 non-null    float64
#  25  No. Affected                 302 non-null    float64
#  26  No. Homeless                 101 non-null    float64
#  27  Total Affected               437 non-null    float64
#  28  Total Damage ('000 US$)      496 non-null    float64
# dtypes: float64(12), int64(4), object(13)
# memory usage: 159.8+ KB

# %%
df.head()
# Out:
#           DisNo. Disaster Subgroup Disaster Type Disaster Subtype Event Name  \
# 1  2000-0021-USA    Meteorological         Storm          Tornado        NaN
# 2  2000-0067-USA    Meteorological         Storm          Tornado        NaN
# 3  2000-0080-USA      Hydrological         Flood   Riverine flood        NaN
# 4  2000-0128-USA    Climatological      Wildfire      Forest fire        NaN
# 5  2000-0175-USA    Meteorological         Storm          Tornado        NaN
#
#    ISO                   Country         Subregion    Region  \
# 1  USA  United States of America  Northern America  Americas
# 2  USA  United States of America  Northern America  Americas
# 3  USA  United States of America  Northern America  Americas
# 4  USA  United States of America  Northern America  Americas
# 5  USA  United States of America  Northern America  Americas
#
#                                             Location  ... Start Day End Year  \
# 1  Crittenden, Daviess, Webster districts (Kentuc...  ...       2.0     2000
# 2  Bullock, Montgomery districts (Alabama provinc...  ...      13.0     2000
# 3                           Kentucky, Ohio provinces  ...      18.0     2000
# 4  Gainesville, Alachua areas (Alachua district, ...  ...      26.0     2000
# 5  Fort Worth Texas city (Tarrant district, Texas...  ...      28.0     2000
#
#    End Month  End Day Total Deaths  No. Injured  No. Affected  No. Homeless  \
# 1          1      4.0          1.0         12.0           NaN         150.0
# 2          2     14.0         22.0        100.0         900.0           NaN
# 3          2     22.0          3.0          NaN         231.0           NaN
# 4          2     26.0          NaN          NaN         600.0           NaN
# 5          3     28.0          5.0          NaN        3000.0         300.0
#
#    Total Affected  Total Damage ('000 US$)
# 1           162.0                 210000.0
# 2          1000.0                      NaN
# 3           231.0                      NaN
# 4           600.0                      NaN
# 5          3300.0                 450000.0
#
# [5 rows x 29 columns]

# %%
import pandas as pd
from meteostat import Daily, Stations
from datetime import datetime

# Ensure essential columns exist
required_columns = ['Start Year', 'Start Month', 'Start Day']
for col in required_columns:
    if col not in df.columns:
        print(f"Missing column: {col}")
        raise KeyError(f"Data is missing required column: {col}")

# Fill missing values with default values
df['Start Day'].fillna(1, inplace=True)
df['Start Month'].fillna(1, inplace=True)
df.dropna(subset=['Start Year'], inplace=True)  # Drop rows with no year

# Convert to integers safely
df['Start Year'] = df['Start Year'].astype(int)
df['Start Month'] = df['Start Month'].astype(int)
df['Start Day'] = df['Start Day'].astype(int)

# Create a new column with a combined date format
df['Date'] = df[['Start Year', 'Start Month', 'Start Day']].apply(
    lambda x: '-'.join(x.astype(str)), axis=1
)

# Convert to datetime using stack/unstack approach
df['Date'] = pd.to_datetime(df['Date'], errors='coerce', format='%Y-%m-%d')

# Drop invalid dates
df.dropna(subset=['Date'], inplace=True)

# Print debug info
print("After datetime conversion:")
print(df[['Date']].head())

# Create an empty list to store weather data
weather_data = []

# Iterate through dataset
for index, row in df.iterrows():
    lat, lon = row['Latitude'], row['Longitude']

    if pd.notna(lat) and pd.notna(lon):  # Use coordinates if available
        try:
            # Find nearest weather station
            stations = Stations().nearby(lat, lon)
            station = stations.fetch(1)  # Get the closest station

            if not station.empty:
                station_id = station.index[0]
                date = row['Date']

                # Fetch weather data
                weather = Daily(station_id, start=date, end=date).fetch()

                if not weather.empty:
                    temp = weather['tavg'].values[0] if 'tavg' in weather.columns else None
                    wind = weather['wspd'].values[0] if 'wspd' in weather.columns else None
                    precip = weather['prcp'].values[0] if 'prcp' in weather.columns else None

                    weather_data.append({
                        'Index': index,
                        'Temperature (C)': temp,
                        'Wind Speed (km/h)': wind,
                        'Precipitation (mm)': precip
                    })
        except Exception as e:
            print(f"Error fetching weather for index {index}: {e}")
    else:
        # No coordinates available, set weather as None
        weather_data.append({'Index': index, 'Temperature (C)': None, 'Wind Speed (km/h)': None, 'Precipitation (mm)': None})

# Convert weather data to DataFrame
weather_df = pd.DataFrame(weather_data)

weather_df.to_csv("weather_data.csv", index=False)
#add index
weather_df['Index'] = weather_df.index
df['Index'] = df.index

# Merge weather data with original dataset
df = pd.merge(df, weather_df, on='Index', how='left')
# Save updated dataset
df.to_csv("disaster_data_with_weather.csv", index=False)

print("Weather data merged successfully!")
# Out:
# After datetime conversion:
#         Date
# 1 2000-01-02
# 2 2000-02-13
# 3 2000-02-18
# 4 2000-02-26
# 5 2000-03-28
# Weather data merged successfully!

# %%
#Add weather reports for each date
# !pip install meteostat
from meteostat import Point, Daily
import datetime
# Out:
# Requirement already satisfied: meteostat in /usr/local/lib/python3.11/dist-packages (1.6.8)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.11/dist-packages (from meteostat) (2.2.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from meteostat) (2025.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from meteostat) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->meteostat) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.17.0)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime

# %%
df = pd.read_csv('/content/disaster_data_with_weather.csv')

# %%
import requests
from bs4 import BeautifulSoup

def extract_climate_news(date, location):
    """Extracts climate-related news headlines for a given date and location.

    Args:
        date: A string representing the date in YYYY-MM-DD format.
        location: A string representing the location (e.g., "California").

    Returns:
        A list of news headlines.
    """

    query = f"climate change {location} {date}"
    url = f"https://news.google.com/search?q={query}&hl=en-US&gl=US&ceid=US%3Aen"

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes

        soup = BeautifulSoup(response.content, "html.parser")

        # Look for all anchor tags with href and within the main content
        headlines = [
            a.get_text().strip() for a in soup.find_all("a", href=True)
            if a.get_text().strip() and len(a.get_text().split()) > 3  # Exclude single words
        ]

        return headlines

    except requests.exceptions.RequestException as e:
        print(f"Error fetching news: {e}")
        return []
# Out:
# Climate-related news headlines for 2010-10-26 in California:
# New U.S. Standards Take Aim at Truck Emissions and Fuel Economy (Published 2010)
# Water, climate change, and sustainability in the southwest
# The California Women's Conference
# The Next Carbon Capture Tool Could be New, Improved Grass
# Space tourism may ignite the effects of global warming
# Camera traps snap first ever photo of Myanmar snub-nosed monkey
# Provincetown Remembers Mary Oliver
# George Soros gives $1m to California's pro-cannabis campaign
# Elusive Charles Koch Deploys Security To Block Joel Francis’ Visit to Koch Industries HQ to Invite Debate on Prop 23
# Los Angeles Lakers: 10 Ways They Can Win The 2010-2011 NBA Championship
# Serving Up Feathered Bait to Attract Ecosystem Data (Published 2010)
# Picture: new monkey discovered in Myanmar
# Navajos Hope to Shift From Coal to Wind and Sun (Published 2010)
# Biological shocker: snake reproduces asexually
# Pelicans in Training (Published 2010)
# Predators Gone, Small Fish Get Bolder (Published 2010)
# Encased in Amber, a Trove of New Species (Published 2010)
# E-Mail Spam Falls After Russian Crackdown (Published 2010)
# Bloomberg’s Latest on Terms: 3 for Him, but Only 2 for Everyone Else (Published 2010)
# Japanese Wineries Betting on a Reviled Grape (Published 2010)
# Pulitzer Prize-winning poet Mary Oliver dies at 83
# Barnes & Noble unveils color Nook with touchscreen
# Yao Ming Injury Could End Career: Power Ranking Best Games For Houston Rockets
# Houston Rockets: 10 Solutions to the Early-Season Woes
# Yao Ming: 10 Moves Rockets Can Make To Stay In Title Race Without Him
# Houston Rockets: Why They Should Trade Yao Ming
# NBA Trade Rumors: 10 Reasons the Houston Rockets Should Trade Yao Ming This Year
# Kira Lee Brazo Obituary - Burney, CA
# NBA Trade Rumors: 10 Reasons Chicago Bulls Need To Pull Trigger On Courtney Lee
# New York Knicks Landry Fields and Other Unexpected NBA Rookie Breakouts
# Yao Ming: Time For Houston Rockets To Panic After Latest Injury?
# Man Pleads Guilty In California-Ohio Pot Case
# NBA Rumors: LeBron James, Kobe Bryant and More Opening Week News
# Leonard F. Kane Obituary - Springfield, IL
# Houston Rockets: 10 Reasons It Isn't Time To Blow It Up and Rebuild
# (PDF) Global Water Pollution and Human Health
# What a 'sweet surprise'! HFCS contains more fructose than believed
# Arnie in the age of ultra-patriotism
# EXCLUSIVE: Mel Gibson To Be Deposed Monday; Will Refuse To Discuss Oksana Beatdown

# %%
# Ensure 'Date' is in datetime format
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Apply the extract_climate_news function
df['News Headlines'] = df['Date'].apply(lambda date: extract_climate_news(date.strftime('%Y-%m-%d'), 'Location') if pd.notna(date) else [])
print(df.head())
# Out:
#           DisNo. Disaster Subgroup Disaster Type Disaster Subtype Event Name  \
# 0  2000-0021-USA    Meteorological         Storm          Tornado        NaN
# 1  2000-0067-USA    Meteorological         Storm          Tornado        NaN
# 2  2000-0080-USA      Hydrological         Flood   Riverine flood        NaN
# 3  2000-0128-USA    Climatological      Wildfire      Forest fire        NaN
# 4  2000-0175-USA    Meteorological         Storm          Tornado        NaN
#
#    ISO                   Country         Subregion    Region  \
# 0  USA  United States of America  Northern America  Americas
# 1  USA  United States of America  Northern America  Americas
# 2  USA  United States of America  Northern America  Americas
# 3  USA  United States of America  Northern America  Americas
# 4  USA  United States of America  Northern America  Americas
#
#                                             Location  ... No. Affected  \
# 0  Crittenden, Daviess, Webster districts (Kentuc...  ...          NaN
# 1  Bullock, Montgomery districts (Alabama provinc...  ...        900.0
# 2                           Kentucky, Ohio provinces  ...        231.0
# 3  Gainesville, Alachua areas (Alachua district, ...  ...        600.0
# 4  Fort Worth Texas city (Tarrant district, Texas...  ...       3000.0
#
#   No. Homeless  Total Affected  Total Damage ('000 US$)       Date  Index  \
# 0        150.0           162.0                 210000.0 2000-01-02      1
# 1          NaN          1000.0                      NaN 2000-02-13      2
# 2          NaN           231.0                      NaN 2000-02-18      3
# 3          NaN           600.0                      NaN 2000-02-26      4
# 4        300.0          3300.0                 450000.0 2000-03-28      5
#
#    Temperature (C)  Wind Speed (km/h)  Precipitation (mm)  \
# 0              NaN                NaN                 NaN
# 1              NaN                NaN                 NaN
# 2              NaN                NaN                 NaN
# 3              NaN                NaN                 NaN
# 4              NaN                NaN                 NaN
#
#                                       News Headlines
# 0  [Knotts offers new direction for Dutch Fork fo...
# 1  [This Day in Weather History: February 13th, S...
# 2  [Hydrological impacts of a wildfire in a Borea...
# 3  [Feb. 24, February, and Winter Season Temperat...
# 4  [Putin’s First Election, March 2000, Forecaste...
#
# [5 rows x 35 columns]

# %%
new_df  = pd.read_csv('/content/disaster_data_with_weather.csv')

# %%
import ee
import geemap.core as geemap
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Authenticate()
ee.Initialize(project='gemini-genai-454500')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
jan_2023_climate = (
    ee.ImageCollection('ECMWF/ERA5_LAND/MONTHLY_AGGR')
    .filterDate('2023-01', '2023-02')
    .first()
)
jan_2023_climate
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.7);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .eerepr {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
#   font-size: 14px;
# }
#
# .eerepr li {
#   list-style-type: none;
#   margin: 0;
# }
#
# .eerepr ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .eerepr > ul {
#   padding-left: 0 !important;
# }
#
# .eerepr summary {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .eerepr summary:hover {
#   color: var(--font-color-primary);
#   background-color: var(--background-color-row-odd)
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .eerepr details > summary::before {
#   content: '▼';
#   display: inline-block;
#   margin-right: 6px;
#   transition: transform 0.2s;
#   transform: rotate(-90deg);
# }
#
# .eerepr details[open] > summary::before {
#   transform: rotate(0deg);
# }
#
# .eerepr details summary::-webkit-details-marker {
#   display:none;
# }
#
# .eerepr details summary {
#   list-style-type: none;
# }
# </style><div class='eerepr'><ul><li><details><summary>Image ECMWF/ERA5_LAND/MONTHLY_AGGR/202301 (150 bands)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>ECMWF/ERA5_LAND/MONTHLY_AGGR/202301</span></li><li><span class='ee-k'>version:</span><span class='ee-v'>1741328216969375</span></li><li><details><summary>bands: List (150 elements)</summary><ul><li><details><summary>0: "dewpoint_temperature_2m", double, EPSG:4326, 3601x1801 px</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>dewpoint_temperature_2m</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [0.1, 0, -180.05, 0, -0.1, 90.05]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>0.1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>-180.05</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>-0.1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>90.05</span></li></ul></details></li><li><details><summary>data_type: double</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>double</span></li></ul></details></li><li><details><summary>dimensions: [3601, 1801]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>3601</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>1801</span></li></ul></details></li></ul></details></li><li><details><summary>1: "temperature_2m", double, EPSG:4326, 3601x1801 px</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>temperature_2m</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [0.1, 0, -180.05, 0, -0.1, 90.05]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>0.1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>-180.05</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>-0.1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>90.05</span></li></ul></details></li><li><details><summary>data_type: double</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>double</span></li></ul></details></li><li><details><summary>dimensions: [3601, 1801]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>3601</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>1801</span></li></ul></details></li></ul></details></li><li><details><summary>2: "skin_temperature", double, EPSG:4326, 3601x1801 px</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>skin_temperature</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [0.1, 0, -180.05, 0, -0.1, 90.05]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>0.1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>-180.05</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>-0.1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>90.05</span></li></ul></details></li><li><details><summary>data_type: double</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>double</span></li></ul></details></li><li><details><summary>dimensions: [3601, 1801]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>3601</span></li><li><span class='ee-k'>1:</span><span cla ...

# %%
m = geemap.Map(center=[30, 0], zoom=2)

vis_params = {
    'bands': ['temperature_2m'],
    'min': 229,
    'max': 304,
    'palette': 'inferno',
}
m.add_layer(jan_2023_climate, vis_params, 'Temperature (K)')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[30, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
# %pip install -q --upgrade altair
import altair as alt
cities = ee.FeatureCollection([
    ee.Feature(ee.Geometry.Point(10.75, 59.91), {'city': 'Oslo'}),
    ee.Feature(ee.Geometry.Point(-118.24, 34.05), {'city': 'Los Angeles'}),
    ee.Feature(ee.Geometry.Point(103.83, 1.33), {'city': 'Singapore'}),
])
cities
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.7);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .eerepr {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
#   font-size: 14px;
# }
#
# .eerepr li {
#   list-style-type: none;
#   margin: 0;
# }
#
# .eerepr ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .eerepr > ul {
#   padding-left: 0 !important;
# }
#
# .eerepr summary {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .eerepr summary:hover {
#   color: var(--font-color-primary);
#   background-color: var(--background-color-row-odd)
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .eerepr details > summary::before {
#   content: '▼';
#   display: inline-block;
#   margin-right: 6px;
#   transition: transform 0.2s;
#   transform: rotate(-90deg);
# }
#
# .eerepr details[open] > summary::before {
#   transform: rotate(0deg);
# }
#
# .eerepr details summary::-webkit-details-marker {
#   display:none;
# }
#
# .eerepr details summary {
#   list-style-type: none;
# }
# </style><div class='eerepr'><ul><li><details><summary>FeatureCollection (3 elements, 2 columns)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>FeatureCollection</span></li><li><details><summary>columns: Object (2 properties)</summary><ul><li><span class='ee-k'>city:</span><span class='ee-v'>String</span></li><li><span class='ee-k'>system:index:</span><span class='ee-v'>String</span></li></ul></details></li><li><details><summary>features: List (3 elements)</summary><ul><li><details><summary>0: Feature (Point, 1 property)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Feature</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>0</span></li><li><details><summary>geometry: Point (10.75, 59.91)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Point</span></li><li><details><summary>coordinates: [10.75, 59.91]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>10.75</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>59.91</span></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>city:</span><span class='ee-v'>Oslo</span></li></ul></details></li></ul></details></li><li><details><summary>1: Feature (Point, 1 property)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Feature</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>1</span></li><li><details><summary>geometry: Point (-118.24, 34.05)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Point</span></li><li><details><summary>coordinates: [-118.24, 34.05]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>-118.24</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>34.05</span></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>city:</span><span class='ee-v'>Los Angeles</span></li></ul></details></li></ul></details></li><li><details><summary>2: Feature (Point, 1 property)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Feature</span></li><li><span class='ee-k'>id:</span><span class='ee-v'>2</span></li><li><details><summary>geometry: Point (103.83, 1.33)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Point</span></li><li><details><summary>coordinates: [103.83, 1.33]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>103.83</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>1.33</span></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>city:</span><span class='ee-v'>Singapore</span></li></ul></details></li></ul></details></li></ul></details></li></ul></details></li></ul></div></div>

# %%
city_climates = jan_2023_climate.reduceRegions(cities, ee.Reducer.first())

city_climates_dataframe = ee.data.computeFeatures(
    {'expression': city_climates, 'fileFormat': 'PANDAS_DATAFRAME'}
)
city_climates_dataframe
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                                                  geo         city  \
# 0   {'type': 'Point', 'coordinates': [10.75, 59.91]}         Oslo
# 1  {'type': 'Point', 'coordinates': [-118.24, 34....  Los Angeles
# 2   {'type': 'Point', 'coordinates': [103.83, 1.33]}    Singapore
#
#    dewpoint_temperature_2m  dewpoint_temperature_2m_max  \
# 0               268.522069                   277.052826
# 1               279.018688                   286.388687
# 2               296.269420                   298.315628
#
#    dewpoint_temperature_2m_min  evaporation_from_bare_soil_max  \
# 0                   255.988235                    2.328306e-10
# 1                   265.190689                    2.328306e-10
# 2                   294.220779                    0.000000e+00
#
#    evaporation_from_bare_soil_min  evaporation_from_bare_soil_sum  \
# 0                       -0.000028                       -0.000109
# 1                       -0.000191                       -0.016581
# 2                       -0.000365                       -0.036704
#
#    evaporation_from_open_water_surfaces_excluding_oceans_max  \
# 0                                       6.047194e-07
# 1                                       1.587765e-05
# 2                                       1.164153e-10
#
#    evaporation_from_open_water_surfaces_excluding_oceans_min  ...  \
# 0                                      -2.328306e-10          ...
# 1                                      -2.093231e-04          ...
# 2                                      -1.259167e-04          ...
#
#    volumetric_soil_water_layer_1_min  volumetric_soil_water_layer_2  \
# 0                           0.240875                       0.277464
# 1                           0.293442                       0.378105
# 2                           0.393356                       0.436111
#
#    volumetric_soil_water_layer_2_max  volumetric_soil_water_layer_2_min  \
# 0                           0.339737                           0.242050
# 1                           0.438995                           0.267899
# 2                           0.520004                           0.405411
#
#    volumetric_soil_water_layer_3  volumetric_soil_water_layer_3_max  \
# 0                       0.288395                           0.312698
# 1                       0.338553                           0.410660
# 2                       0.436325                           0.519806
#
#    volumetric_soil_water_layer_3_min  volumetric_soil_water_layer_4  \
# 0                           0.263550                       0.283256
# 1                           0.196136                       0.217798
# 2                           0.401047                       0.496528
#
#    volumetric_soil_water_layer_4_max  volumetric_soil_water_layer_4_min
# 0                           0.291718                           0.269760
# 1                           0.233704                           0.208649
# 2                           0.510345                           0.489883
#
# [3 rows x 152 columns]

# %%
alt.Chart(city_climates_dataframe).mark_bar(size=100).encode(
    alt.X('city:N', sort='y', axis=alt.Axis(labelAngle=0), title='City'),
    alt.Y('temperature_2m:Q', title='Temperature (K)'),
    tooltip=[
        alt.Tooltip('city:N', title='City'),
        alt.Tooltip('temperature_2m:Q', title='Temperature (K)'),
    ],
).properties(title='January 2023 temperature for selected cities', width=500)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# alt.Chart(...)

# %%
# Create arbitrary constant images.
constant_1 = ee.Image(1)
constant_2 = ee.Image(2)

# Create a collection by giving a list to the constructor.
collection_from_constructor = ee.ImageCollection([constant_1, constant_2])
display('Collection from constructor:', collection_from_constructor)

# Create a collection with fromImages().
collection_from_images = ee.ImageCollection.fromImages(
    [ee.Image(3), ee.Image(4)]
)
display('Collection from images:', collection_from_images)

# Merge two collections.
merged_collection = collection_from_constructor.merge(collection_from_images)
display('Merged collection:', merged_collection)

# Create a toy FeatureCollection
features = ee.FeatureCollection(
    [ee.Feature(None, {'foo': 1}), ee.Feature(None, {'foo': 2})]
)

# Create an ImageCollection from the FeatureCollection
# by mapping a function over the FeatureCollection.
images = features.map(lambda feature: ee.Image(ee.Number(feature.get('foo'))))

# Display the resultant collection.
display('Image collection:', images)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 'Collection from constructor:'
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.7);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .eerepr {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
#   font-size: 14px;
# }
#
# .eerepr li {
#   list-style-type: none;
#   margin: 0;
# }
#
# .eerepr ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .eerepr > ul {
#   padding-left: 0 !important;
# }
#
# .eerepr summary {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .eerepr summary:hover {
#   color: var(--font-color-primary);
#   background-color: var(--background-color-row-odd)
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .eerepr details > summary::before {
#   content: '▼';
#   display: inline-block;
#   margin-right: 6px;
#   transition: transform 0.2s;
#   transform: rotate(-90deg);
# }
#
# .eerepr details[open] > summary::before {
#   transform: rotate(0deg);
# }
#
# .eerepr details summary::-webkit-details-marker {
#   display:none;
# }
#
# .eerepr details summary {
#   list-style-type: none;
# }
# </style><div class='eerepr'><ul><li><details><summary>ImageCollection (2 elements)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>ImageCollection</span></li><li><details><summary>bands: []</summary><ul></ul></details></li><li><details><summary>features: List (2 elements)</summary><ul><li><details><summary>0: Image (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "constant", int ∈ [1, 1], EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>constant</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [1, 0, 0, 0, 1, 0]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></details></li><li><details><summary>data_type: int ∈ [1, 1]</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>system:index:</span><span class='ee-v'>0</span></li></ul></details></li></ul></details></li><li><details><summary>1: Image (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "constant", int ∈ [2, 2], EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>constant</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [1, 0, 0, 0, 1, 0]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></details></li><li><details><summary>data_type: int ∈ [2, 2]</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>2</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>2</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>system:index:</span><span class='ee-v'>1</span></li></ul></details></li></ul></details></li></ul></details></li></ul></details></li></ul></div></div>
# 'Collection from images:'
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.7);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .eerepr {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
#   font-size: 14px;
# }
#
# .eerepr li {
#   list-style-type: none;
#   margin: 0;
# }
#
# .eerepr ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .eerepr > ul {
#   padding-left: 0 !important;
# }
#
# .eerepr summary {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .eerepr summary:hover {
#   color: var(--font-color-primary);
#   background-color: var(--background-color-row-odd)
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .eerepr details > summary::before {
#   content: '▼';
#   display: inline-block;
#   margin-right: 6px;
#   transition: transform 0.2s;
#   transform: rotate(-90deg);
# }
#
# .eerepr details[open] > summary::before {
#   transform: rotate(0deg);
# }
#
# .eerepr details summary::-webkit-details-marker {
#   display:none;
# }
#
# .eerepr details summary {
#   list-style-type: none;
# }
# </style><div class='eerepr'><ul><li><details><summary>ImageCollection (2 elements)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>ImageCollection</span></li><li><details><summary>bands: []</summary><ul></ul></details></li><li><details><summary>features: List (2 elements)</summary><ul><li><details><summary>0: Image (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "constant", int ∈ [3, 3], EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>constant</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [1, 0, 0, 0, 1, 0]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></details></li><li><details><summary>data_type: int ∈ [3, 3]</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>3</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>3</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>system:index:</span><span class='ee-v'>0</span></li></ul></details></li></ul></details></li><li><details><summary>1: Image (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "constant", int ∈ [4, 4], EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>constant</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [1, 0, 0, 0, 1, 0]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></details></li><li><details><summary>data_type: int ∈ [4, 4]</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>4</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>4</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>system:index:</span><span class='ee-v'>1</span></li></ul></details></li></ul></details></li></ul></details></li></ul></details></li></ul></div></div>
# 'Merged collection:'
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.7);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .eerepr {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
#   font-size: 14px;
# }
#
# .eerepr li {
#   list-style-type: none;
#   margin: 0;
# }
#
# .eerepr ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .eerepr > ul {
#   padding-left: 0 !important;
# }
#
# .eerepr summary {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .eerepr summary:hover {
#   color: var(--font-color-primary);
#   background-color: var(--background-color-row-odd)
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .eerepr details > summary::before {
#   content: '▼';
#   display: inline-block;
#   margin-right: 6px;
#   transition: transform 0.2s;
#   transform: rotate(-90deg);
# }
#
# .eerepr details[open] > summary::before {
#   transform: rotate(0deg);
# }
#
# .eerepr details summary::-webkit-details-marker {
#   display:none;
# }
#
# .eerepr details summary {
#   list-style-type: none;
# }
# </style><div class='eerepr'><ul><li><details><summary>ImageCollection (4 elements)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>ImageCollection</span></li><li><details><summary>bands: []</summary><ul></ul></details></li><li><details><summary>features: List (4 elements)</summary><ul><li><details><summary>0: Image (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "constant", int ∈ [1, 1], EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>constant</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [1, 0, 0, 0, 1, 0]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></details></li><li><details><summary>data_type: int ∈ [1, 1]</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>system:index:</span><span class='ee-v'>1_0</span></li></ul></details></li></ul></details></li><li><details><summary>1: Image (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "constant", int ∈ [2, 2], EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>constant</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [1, 0, 0, 0, 1, 0]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></details></li><li><details><summary>data_type: int ∈ [2, 2]</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>2</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>2</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>system:index:</span><span class='ee-v'>1_1</span></li></ul></details></li></ul></details></li><li><details><summary>2: Image (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "constant", int ∈ [3, 3], EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>constant</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [1, 0, 0, 0, 1, 0]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee ...
# 'Image collection:'
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.7));
#   --font-color-accent: rgba(123, 31, 162, 1);
#   --border-color: var(--jp-border-color2, #e0e0e0);
#   --background-color: var(--jp-layout-color0, white);
#   --background-color-row-even: var(--jp-layout-color1, white);
#   --background-color-row-odd: var(--jp-layout-color2, #eeeeee);
# }
#
# html[theme="dark"],
# body[data-theme="dark"],
# body.vscode-dark {
#   --font-color-primary: rgba(255, 255, 255, 1);
#   --font-color-secondary: rgba(255, 255, 255, 0.7);
#   --font-color-accent: rgb(173, 132, 190);
#   --border-color: #2e2e2e;
#   --background-color: #111111;
#   --background-color-row-even: #111111;
#   --background-color-row-odd: #313131;
# }
#
# .eerepr {
#   padding: 1em;
#   line-height: 1.5em;
#   min-width: 300px;
#   max-width: 1200px;
#   overflow-y: scroll;
#   max-height: 600px;
#   border: 1px solid var(--border-color);
#   font-family: monospace;
#   font-size: 14px;
# }
#
# .eerepr li {
#   list-style-type: none;
#   margin: 0;
# }
#
# .eerepr ul {
#   padding-left: 1.5em !important;
#   margin: 0;
# }
#
# .eerepr > ul {
#   padding-left: 0 !important;
# }
#
# .eerepr summary {
#   color: var(--font-color-secondary);
#   cursor: pointer;
#   margin: 0;
# }
#
# .eerepr summary:hover {
#   color: var(--font-color-primary);
#   background-color: var(--background-color-row-odd)
# }
#
# .ee-k {
#   color: var(--font-color-accent);
#   margin-right: 6px;
# }
#
# .ee-v {
#   color: var(--font-color-primary);
# }
#
# .eerepr details > summary::before {
#   content: '▼';
#   display: inline-block;
#   margin-right: 6px;
#   transition: transform 0.2s;
#   transform: rotate(-90deg);
# }
#
# .eerepr details[open] > summary::before {
#   transform: rotate(0deg);
# }
#
# .eerepr details summary::-webkit-details-marker {
#   display:none;
# }
#
# .eerepr details summary {
#   list-style-type: none;
# }
# </style><div class='eerepr'><ul><li><details><summary>ImageCollection (2 elements)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>ImageCollection</span></li><li><details><summary>bands: []</summary><ul></ul></details></li><li><details><summary>features: List (2 elements)</summary><ul><li><details><summary>0: Image (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "constant", int ∈ [1, 1], EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>constant</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [1, 0, 0, 0, 1, 0]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></details></li><li><details><summary>data_type: int ∈ [1, 1]</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>system:index:</span><span class='ee-v'>0</span></li></ul></details></li></ul></details></li><li><details><summary>1: Image (1 band)</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>Image</span></li><li><details><summary>bands: List (1 element)</summary><ul><li><details><summary>0: "constant", int ∈ [2, 2], EPSG:4326</summary><ul><li><span class='ee-k'>id:</span><span class='ee-v'>constant</span></li><li><span class='ee-k'>crs:</span><span class='ee-v'>EPSG:4326</span></li><li><details><summary>crs_transform: [1, 0, 0, 0, 1, 0]</summary><ul><li><span class='ee-k'>0:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>1:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>2:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>3:</span><span class='ee-v'>0</span></li><li><span class='ee-k'>4:</span><span class='ee-v'>1</span></li><li><span class='ee-k'>5:</span><span class='ee-v'>0</span></li></ul></details></li><li><details><summary>data_type: int ∈ [2, 2]</summary><ul><li><span class='ee-k'>type:</span><span class='ee-v'>PixelType</span></li><li><span class='ee-k'>max:</span><span class='ee-v'>2</span></li><li><span class='ee-k'>min:</span><span class='ee-v'>2</span></li><li><span class='ee-k'>precision:</span><span class='ee-v'>int</span></li></ul></details></li></ul></details></li></ul></details></li><li><details><summary>properties: Object (1 property)</summary><ul><li><span class='ee-k'>system:index:</span><span class='ee-v'>1</span></li></ul></details></li></ul></details></li></ul></details></li></ul></details></li></ul></div></div>

# %%
# All the GeoTiffs are in this folder.
uri_base = (
    'gs://gcp-public-data-landsat/LC08/01/001/002/'
    + 'LC08_L1GT_001002_20160817_20170322_01_T2/'
)

# List of URIs, one for each band.
uris = ee.List([
    uri_base + 'LC08_L1GT_001002_20160817_20170322_01_T2_B2.TIF',
    uri_base + 'LC08_L1GT_001002_20160817_20170322_01_T2_B3.TIF',
    uri_base + 'LC08_L1GT_001002_20160817_20170322_01_T2_B4.TIF',
    uri_base + 'LC08_L1GT_001002_20160817_20170322_01_T2_B5.TIF',
])

# Make a collection from the list of images.
images = uris.map(lambda uri: ee.Image.loadGeoTIFF(uri))
collection = ee.ImageCollection(images)

# Get an RGB image from the collection of bands.
rgb = collection.toBands().rename(['B2', 'B3', 'B4', 'B5'])
m = geemap.Map()
m.center_object(rgb)
m.add_layer(rgb, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 20000}, 'rgb')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text'…

# %%
'''
Satellites in interest
NASA/ORNL/DAYMET_V4 1981/01/01 - 2022/12/31
NOAA/CFSV2/FOR6H 1977/01/01 - 2022/12/31
ECMWF/CAMS/NRT - 2017/01/01 - 2022/12/31

TASK get their images , 3 images per satteliet per month, total 9 images per month, extract as jpg, save into google cloud bucket
'''

# %%
# prompt: ee.Initialize(project='gemini-genai-454500')
# # Define your Google Cloud Storage bucket and folder
# bucket_name = 'satellite-images-genai'  # Replace with your bucket name
# folder_name = 'satellite_images'
# # Define the satellite image collections and their date ranges
# satellite_collections = {
#     'NASA/ORNL/DAYMET_V4': ('1981-01-01', '2022-12-31'),
#     'NOAA/CFSV2/FOR6H': ('1977-01-01', '2022-12-31'),
#     'ECMWF/CAMS/NRT': ('2017-01-01', '2022-12-31'),
# }
# # Define the region for North America (bounding box)
# region = ee.Geometry.Rectangle([-170, 15, -50, 70])  # North America
# # Visualization parameters for specific datasets
# def get_vis_params(collection_id):
#     if collection_id == 'ECMWF/CAMS/NRT':
#         return {
#             'bands': ['total_aerosol_optical_depth_at_550nm_surface'],
#             'min': 0.0,
#             'max': 3.6,
#             'palette': [
#                 '5e4fa2', '3288bd', '66c2a5', 'abe0a4', 'e6f598', 'ffffbf',
#                 'fee08b', 'fdae61', 'f46d43', 'd53e4f', '9e0142'
#             ]
#         }
#     elif collection_id == 'NASA/ORNL/DAYMET_V4':
#         return {
#             'bands': ['tmax'],
#             'min': -40.0,
#             'max': 30.0,
#             'palette': ['1621A2', 'white', 'cyan', 'green', 'yellow', 'orange', 'red']
#         }
#     elif collection_id == 'NOAA/CFSV2/FOR6H':
#         return {
#             'bands': ['Temperature_height_above_ground'],
#             'min': 220.0,
#             'max': 310.0,
#             'palette': ['blue', 'purple', 'cyan', 'green', 'yellow', 'red']
#         }
#     else:
#         return {}
# TASK - Every month from metnioned dates, take 3 pictures of different dates from each satellite, total 9 images, save them as jpg in bucket with foldername satelliteimages/<year-month>

import ee
import datetime
import os

# Initialize Earth Engine
ee.Authenticate()
ee.Initialize(project='gemini-genai-454500')

# Define your Google Cloud Storage bucket and folder
bucket_name = 'satellite-images-genai'  # Replace with your bucket name
folder_name = 'satellite_images'

# Define the satellite image collections and their date ranges
satellite_collections = {
    'NASA/ORNL/DAYMET_V4': ('1981-01-01', '2022-12-31'),
    'NOAA/CFSV2/FOR6H': ('1977-01-01', '2022-12-31'),
    'ECMWF/CAMS/NRT': ('2017-01-01', '2022-12-31'),
}

# Define the region for North America (bounding box)
region = ee.Geometry.Rectangle([-170, 15, -50, 70])  # North America

# Visualization parameters for specific datasets
def get_vis_params(collection_id):
    if collection_id == 'ECMWF/CAMS/NRT':
        return {
            'bands': ['total_aerosol_optical_depth_at_550nm_surface'],
            'min': 0.0,
            'max': 3.6,
            'palette': [
                '5e4fa2', '3288bd', '66c2a5', 'abe0a4', 'e6f598', 'ffffbf',
                'fee08b', 'fdae61', 'f46d43', 'd53e4f', '9e0142'
            ]
        }
    elif collection_id == 'NASA/ORNL/DAYMET_V4':
        return {
            'bands': ['tmax'],
            'min': -40.0,
            'max': 30.0,
            'palette': ['1621A2', 'white', 'cyan', 'green', 'yellow', 'orange', 'red']
        }
    elif collection_id == 'NOAA/CFSV2/FOR6H':
        return {
            'bands': ['Temperature_height_above_ground'],
            'min': 220.0,
            'max': 310.0,
            'palette': ['blue', 'purple', 'cyan', 'green', 'yellow', 'red']
        }
    else:
        return {}


def export_satellite_images(collection_id, start_date, end_date, region):
  """Exports satellite images to Google Cloud Storage."""
  collection = ee.ImageCollection(collection_id).filterDate(start_date, end_date)
  vis_params = get_vis_params(collection_id)
  if not vis_params:
    print(f"No visualization parameters found for {collection_id}. Skipping...")
    return

  image_list = collection.toList(collection.size())

  for i in range(min(3, collection.size().getInfo())):
      image = ee.Image(image_list.get(i))
      date_str = image.date().format('YYYY-MM-dd').getInfo()
      year_month = date_str[:7]
      output_filename = f'{folder_name}/{year_month}/image_{collection_id[:4]}.jpg'


      task = ee.batch.Export.image.toCloudStorage(
          image=image.visualize(**vis_params),
          description = f"Exporting_{collection_id[:4]}"[:50],
          bucket=bucket_name,
          fileNamePrefix=output_filename,
          region=region.getInfo()['coordinates'],
          fileFormat='GEO_TIFF',
          maxPixels=1e13
      )
      task.start()
      print(f'Exporting {collection_id} image to {output_filename}...')




# Iterate through satellite collections and export images
for collection_id, (start_date, end_date) in satellite_collections.items():
  start_year = int(start_date[:4])
  end_year = int(end_date[:4])
  for year in range(start_year, end_year + 1):
    for month in range(1, 13):
      start_month_date = datetime.date(year, month, 1).strftime('%Y-%m-%d')
      end_month_date = (datetime.date(year, month + 1, 1)
                      if month < 12 else datetime.date(year + 1, 1, 1)).strftime('%Y-%m-%d')
      export_satellite_images(collection_id, start_month_date, end_month_date, region)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1981-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1982-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1983-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1984-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1985-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1986-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1987-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1988-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1989-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1990-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1991-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1992-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1993-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1994-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1995-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-01/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-02/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-03/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-04/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-05/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-06/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-07/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-08/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-09/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-10/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-11/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-12/image_NASA.jpg...
# Exporting NASA/ORNL/DAYMET_V4 image to satellite_images/1996-12/image_NASA.jpg...
# ...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1994-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1994-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1994-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1995-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1996-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1997-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1998-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-07/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-08/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-09/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-10/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-11/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/1999-12/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-01/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-02/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-03/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-04/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-05/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-06/image_NOAA.jpg...
# Exporting NOAA/CFSV2/FOR6H image to satellite_images/2000-07/image_NOAA.jpg...
